# %%
import pandas as pd
df= pd.read_csv('/content/analysis_id (1)(in).csv')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              5000 non-null   int64
#  1   date_hour               5000 non-null   object
#  2   client                  5000 non-null   object
#  3   device_type             5000 non-null   object
#  4   time_zone               5000 non-null   object
#  5   os_name                 5000 non-null   object
#  6   browser_name            5000 non-null   object
#  7   ad_unit                 5000 non-null   object
#  8   size                    5000 non-null   object
#  9   bidder                  5000 non-null   object
#  10  bid_range               5000 non-null   object
#  11  media_type              5000 non-null   object
#  12  request_count           5000 non-null   int64
#  13  response_count          5000 non-null   int64
#  14  prebid_win_count        1167 non-null   float64
#  15  win_count               186 non-null    float64
#  16  sum_bid                 3790 non-null   float64
#  17  sum_time_to_respond     3790 non-null   float64
#  18  median                  1760 non-null   float64
#  19  min_bid                 3790 non-null   float64
#  20  max_bid                 3790 non-null   float64
#  21  avg_bid                 3790 non-null   float64
#  22  sum_2nd_highest_bid     734 non-null    float64
#  23  sum_prebid_winning_bid  1167 non-null   float64
#  24  sum_winning_bid         186 non-null    float64
#  25  sum_nobid               0 non-null      float64
#  26  sum_timeout             0 non-null      float64
# dtypes: float64(13), int64(3), object(11)
# memory usage: 1.0+ MB

# %%
df.head(10)
# Out:
#    Unnamed: 0            date_hour     client device_type        time_zone  \
# 0           0  2021-04-11T01:00:00  asc126828     Desktop  America/Chicago
# 1           1  2021-04-11T01:00:00  asc126828     Desktop  America/Chicago
# 2           2  2021-04-11T01:00:00  asc126828     Desktop  America/Chicago
# 3           3  2021-04-11T01:00:00  asc126828     Desktop  America/Chicago
# 4           4  2021-04-11T01:00:00  asc126828     Desktop  America/Chicago
# 5           5  2021-04-11T01:00:00  asc126828     Desktop  America/Chicago
# 6           6  2021-04-11T01:00:00  asc126828     Desktop  America/Chicago
# 7           7  2021-04-11T01:00:00  asc126828     Desktop  America/Chicago
# 8           8  2021-04-11T01:00:00  asc126828     Desktop  America/Chicago
# 9           9  2021-04-11T01:00:00  asc126828     Desktop  America/Chicago
#
#   os_name        browser_name                       ad_unit     size  \
# 0   Linux  Chrome-85.04183133       div-gpt-ad-BT-D-Footers   728x90
# 1   Linux  Chrome-85.04183133       div-gpt-ad-BT-D-Footers   728x90
# 2   Linux  Chrome-85.04183133      div-gpt-ad-BT-D-InLine-1  300x250
# 3   Linux  Chrome-85.04183133   div-gpt-ad-BT-D-O-300x250-1  300x250
# 4   Linux  Chrome-85.04183133   div-gpt-ad-BT-D-O-300x250-1  300x250
# 5   Linux  Chrome-85.04183133   div-gpt-ad-BT-D-O-300x250-3  300x250
# 6   Linux  Chrome-85.04183133  div-gpt-ad-BT-D-Responsive-B   468x60
# 7   Linux  Chrome-85.04183133  div-gpt-ad-BT-D-Responsive-T   728x90
# 8   Linux  Chrome-85.04183133     div-gpt-ad-BT-D-SideBar-1  300x250
# 9   Linux  Chrome-85.04183133     div-gpt-ad-BT-D-SideBar-T  300x600
#
#        bidder  ... sum_time_to_respond   median   min_bid   max_bid   avg_bid  \
# 0   onemobile  ...              6614.0      NaN  0.585200  0.585200  0.585200
# 1   rhythmone  ...              5171.0      NaN  0.339450  0.348750  0.344100
# 2   undertone  ...              1523.0      NaN  0.960000  0.960000  0.960000
# 3              ...                 NaN      NaN       NaN       NaN       NaN
# 4   rhythmone  ...              3570.0  0.34875  0.344100  0.348750  0.346425
# 5  pulsepoint  ...              1413.0  0.48020  0.480200  0.480200  0.480200
# 6              ...                 NaN      NaN       NaN       NaN       NaN
# 7    pubmatic  ...              4823.0      NaN  0.244400  0.272600  0.263200
# 8   onemobile  ...              2064.0      NaN  1.036109  1.036109  1.036109
# 9   onemobile  ...              1896.0      NaN  0.709107  0.709107  0.709107
#
#    sum_2nd_highest_bid  sum_prebid_winning_bid  sum_winning_bid  sum_nobid  \
# 0               0.5852                0.585200              NaN        NaN
# 1                  NaN                     NaN              NaN        NaN
# 2                  NaN                     NaN              NaN        NaN
# 3                  NaN                     NaN              NaN        NaN
# 4                  NaN                     NaN              NaN        NaN
# 5                  NaN                     NaN              NaN        NaN
# 6                  NaN                     NaN              NaN        NaN
# 7                  NaN                     NaN              NaN        NaN
# 8                  NaN                     NaN              NaN        NaN
# 9                  NaN                0.709107              NaN        NaN
#
#    sum_timeout
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
#
# [10 rows x 27 columns]

# %%
import pandas as pd
df= pd.read_csv('/content/analysis_id (1)(in).csv')

df.info()

df.columns=[col.lower().strip() for col in df.columns]

bid_stat= df.groupby('bidder')[['response_count','prebid_win_count']].sum().reset_index()

bid_stat['win_rate']=bid_stat['prebid_win_count']/bid_stat['response_count']

bid_stat= bid_stat[bid_stat['response_count']>0]

bid_stat= bid_stat.sort_values(by='win_rate',ascending=False)

bid_stat.head()

# %%
bid_stat.head()
# Out:
#           bidder  response_count  prebid_win_count  win_rate
# 17     undertone             104              52.0  0.500000
# 15         teads             700             323.0  0.461429
# 10    pulsepoint             191              71.0  0.371728
# 13  sharethrough             332             104.0  0.313253
# 7      onemobile            2726             759.0  0.278430
